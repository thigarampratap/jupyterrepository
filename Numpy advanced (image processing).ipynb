# %%
import numpy as np

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
from skimage import io
from matplotlib import pyplot as plt

# %%
flower = io.imread('favpic.jpg')
type(flower)
# Out:
# numpy.ndarray

# %%
flower.shape
# Out:
# (4000, 6000, 3)

# %%
plt.imshow(flower)

# %%
print(plt.imshow(flower[:1000, 900:2200]))
print(plt.imshow(flower[1800:3300, 1100:2800]))
# Out:
# AxesImage(54,36;334.8x217.44)
# AxesImage(54,36;334.8x217.44)

# %%
np.tan(flower)
# Out:
# array([[[ 1.2217e+00,  8.3281e+00, -2.0410e+00],
#         [-3.0781e+00, -8.2568e-01, -1.1554e-01],
#         [-4.2065e-01,  1.6980e-01,  9.1943e-01],
#         ...,
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01],
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01],
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01]],
#
#        [[-3.0781e+00, -8.2568e-01, -1.1554e-01],
#         [-1.1554e-01,  4.8462e-01,  1.6523e+00],
#         [ 1.2217e+00,  8.3281e+00, -2.0410e+00],
#         ...,
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01],
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01],
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01]],
#
#        [[ 6.8652e-01,  2.3477e+00, -5.7383e+00],
#         [-3.0781e+00, -8.2568e-01, -1.1554e-01],
#         [-1.1554e-01,  4.8462e-01,  1.6523e+00],
#         ...,
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01],
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01],
#         [ 0.0000e+00, -2.9102e-01, -2.9102e-01]],
#
#        ...,
#
# ...

# %%
a1 = np.array([3, 5, 6, 3, 2, 9])

# %%
a1 > 4
# Out:
# array([False,  True,  True, False, False,  True])

# %%
a1 < 5
# Out:
# array([ True, False, False,  True,  True, False])

# %%
a1[a1 < 4]
# Out:
# array([3, 3, 2])

# %%
fm = np.where(flower > 180, 255, 0)
plt.imshow(fm)

# %%
a2 = np.array([1, 2, 3, 4, 5, 6])
print('a1', a1)
print('a2', a2)
# Out:
# a1 [3 5 6 3 2 9]
# a2 [1 2 3 4 5 6]

# %%
a1 + a2
# Out:
# array([ 4,  7,  9,  7,  7, 15])

# %%
a1 * a2
# Out:
# array([ 3, 10, 18, 12, 10, 54])

# %%
a1 * 10
# Out:
# array([30, 50, 60, 30, 20, 90])

# %%
from skimage import io
from matplotlib import pyplot as plt

# %%
budda = io.imread('budda.jpg')

# %%
budda
type(budda)
budda.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(budda)

# %%
budda.shape
# Out:
# (4000, 6000, 3)

# %%
budda1 = budda.reshape(6000, 4000, 3)

# %%
plt.imshow(budda1)

# %%
plt.imshow(budda[:2000, 2000:4000])

# %%
plt.imshow(np.where(budda > 150, 255, 3))

# %%
np.tan(budda)
# Out:
# array([[[ 3.3960e-01,  2.6566e-02, -1.4980e+00],
#         [ 3.3960e-01,  2.6566e-02, -1.4980e+00],
#         [ 4.0273e+00, -1.1554e-01,  1.6201e+00],
#         ...,
#         [-1.3354e-01, -7.5312e+01, -4.5239e-01],
#         [-2.8149e-01,  7.7500e+00, -6.3574e-01],
#         [-6.2354e-01,  2.2910e+00, -1.1377e+00]],
#
#        [[ 5.0684e-01,  1.6980e-01, -1.1172e+00],
#         [-7.9639e-01, -1.4697e+00,  2.2910e+00],
#         [-1.0596e+00, -2.0410e+00,  1.6201e+00],
#         ...,
#         [-3.2734e+00,  4.7388e-01, -2.2600e+02],
#         [-6.4062e+00,  3.1030e-01,  7.2461e+00],
#         [-6.2354e-01,  2.2910e+00, -1.1377e+00]],
#
#        [[-2.5094e+01,  3.7441e+00,  3.1030e-01],
#         [ 5.0684e-01,  1.6980e-01, -1.1172e+00],
#         [ 3.3960e-01,  2.6566e-02, -1.4980e+00],
#         ...,
#         [-3.2734e+00,  4.7388e-01, -2.2600e+02],
#         [-2.8149e-01,  7.7500e+00, -6.3574e-01],
#         [-4.4165e-01,  3.6152e+00, -8.5596e-01]],
#
#        ...,
#
# ...
